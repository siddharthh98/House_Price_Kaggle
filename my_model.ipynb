# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
trainset = pd.read_csv("train.csv")
testset = pd.read_csv("test.csv")

# %%
trainset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
print(trainset.columns[trainset.isnull().sum() > 0].tolist())
# Out:
# ['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature']

# %% [markdown]
# MSSubclass,  MSZoining(OneHotEncoding required), LotFrontage, LotArea, Street(OneHotEncoding required), Alley(OneHotEncoding required), LotShape(OneHotEncoding required), LandContour(OneHotEncoding required), Utilities(OneHotEncoding Required), LotConfig(OneHotEncoding required), LandSlope(OneHotEncoding required), Neighborhood(OneHotEncoding required), Condition1(OneHotEncoding required), Condition2(OneHotEncoding required), BldgType(OneHotEncoding required), HouseStyle(OneHotEncoding required), OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle(OneHotEncoding required), RoofMat1(OneHotEncoding required), Exterior1st(OneHotEncoding required), Exterior2nd(OneHotEncoding required), MasVnrType(OneHotEncoding required), MasVnrArea, ExterQual(OneHotEncoding required), ExterCond(OneHotEncoding required), Foundation(OneHotEncoding required), BsmtQual(OneHotEncoding required), BsmtCond(OneHotEncoding required), BsmtExposure(OneHotEncoding required), BsmtFinType1(OneHotEncoding required), BsmtFinSF1, BsmtFinType2(OneHotEncoding requied), BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating(OneHotEncoding required), HeatingQC(OneHotEncoding required), CentralAir(OneHotEncoding required), Electrical(OneHotEncoding requied), 1stFlrSf, 2ndFlrSF, LowQualFinSF, GrLiveArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, Bedroom, Kitchen, KitchenQual(OneHotEncoding required), TotRmsAbvGrid, Functional(OneHotEncoding required), Fireplaces, FireplaceQu(OneHotEncoding required), GarageType(OneHotEncoding required), GarageType(OneHotEncoding required), GarageYrBlt, GarageFinish(OneHotEncoding required), GarageCars, GarageArea, GarageQual(OneHotEncoding required), GarageCond(OneHotEncoding required),PavedDrive(OneHotEncoding required), WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC(OneHotEncoding required), Fence(OneHotEncoding required), MiscFeature(OneHotEncoding required), MiscVal, MoSold, YrSold, SaleType(OneHotEncoding required), SaleCondition(OneHotEncoding required),

# %% [markdown]
# Columns in which imputation is needed:
# LotFrontage, MasVnrArea, GarageYrBlt

# %% [markdown]
# These columns drop first and check the accuracy if good then leave it there only otherwise do sum nlp on it.
# MSZoning, Alley, Utilites, Exterior1st, Exterior2nd, MaVnrType, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinType2, KitchenQual, Functional, Electrical, FireplaceQu, GarageType, GarageFinish, GarageQual, GarageCond, PoolQC, Fence, MiscFeature, SaleType.

# %%
print(testset.columns[testset.isnull().sum() > 0].tolist())
# Out:
# ['MSZoning', 'LotFrontage', 'Alley', 'Utilities', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType']

# %% [markdown]
# Columns in which imputation is needed: LotFrontage, MasVnrArea, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, BsmtFullBath, BsmtHalfBath, GarageYrBlt, GarageCars, GarageArea.

# %%
columns_to_drop = ['MSZoning', 'Alley', 'Utilities', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'BsmtQual', 'BsmtCond', 
                   'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType',
                   'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'Electrical']

# %%
trainset.drop(columns_to_drop, axis=1,inplace=True)

# %%
testset.drop(columns_to_drop, axis=1, inplace=True)

# %%
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
le = LabelEncoder()

# %%
temp_string = ['Street', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
              'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'ExterQual', 'ExterCond', 'Foundation', 'Heating', 'HeatingQC',
              'CentralAir', 'PavedDrive', 'SaleCondition']

# %%
for column in temp_string:
    trainset[column] = le.fit_transform(trainset[column])

# %%
for column in temp_string:
    testset[column] = le.fit_transform(testset[column])

# %%
trainset.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0   1          60         65.0     8450       1         3            3
# 1   2          20         80.0     9600       1         3            3
# 2   3          60         68.0    11250       1         0            3
# 3   4          70         60.0     9550       1         0            3
# 4   5          60         84.0    14260       1         0            3
#
#    LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# 0          4          0             5           2           2         0
# 1          2          0            24           1           2         0
# 2          4          0             5           2           2         0
# 3          0          0             6           2           2         0
# 4          2          0            15           2           2         0
#
#    HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  RoofStyle  \
# ...

# %%
testset.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0  1461          20         80.0    11622       1         3            3
# 1  1462          20         81.0    14267       1         0            3
# 2  1463          60         74.0    13830       1         0            3
# 3  1464          60         78.0     9978       1         0            3
# 4  1465         120         43.0     5005       1         0            1
#
#    LotConfig  LandSlope  Neighborhood  Condition1  Condition2  BldgType  \
# 0          4          0            12           1           2         0
# 1          0          0            12           2           2         0
# 2          4          0             8           2           2         0
# 3          4          0             8           2           2         0
# 4          4          0            22           2           2         4
#
#    HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  RoofStyle  \
# ...

# %%
my_imputer = Imputer()

# %%
train_y = trainset.SalePrice

# %%
train_X = trainset.drop(['SalePrice'], axis=1)

# %%
test_X = testset

# %%
train_X = my_imputer.fit_transform(train_X)

# %%
test_X = my_imputer.fit_transform(test_X)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
clf = RandomForestRegressor()

# %%
clf.fit(train_X, train_y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
y_predict = clf.predict(test_X)

# %%
my_submission = pd.DataFrame({'Id':testset.Id, 'SalePrice':y_predict})

# %%
my_submission.to_csv('submission.csv', index=False)
